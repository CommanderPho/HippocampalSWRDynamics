# %% [markdown]
# # Figure 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import replay_structure.metadata as meta
import replay_structure.read_write as read_write
from replay_structure.utils import get_marginal_sum, get_p_models
import importlib

# %%
SMALL_SIZE = 5
MEDIUM_SIZE = 6
BIGGER_SIZE = 7

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.rcParams["axes.linewidth"] = 1
small_axislabel_fontsize=5

# %% [markdown]
# ### Load data (marginals, map trajectories, model comparison results) for plotting rat1day1 examples

# %%
session_idx: int = 1
session = meta.Session_List[session_idx]
print(f'session_idx: {session_idx}, session: {session}')

# tries to load all the exported position marginals
spikemat_list = np.arange(322)
ripple_marginals = dict()
for spikemat_ind in spikemat_list:
    try:
        ripple_marginals[spikemat_ind] = read_write.load_marginals(
            session, spikemat_ind, meta.Ripple_Data.default_time_window_ms, meta.Ripple_Data.name, meta.Ripple_Data.default_likelihood_function)
    except (FileNotFoundError) as err:
        print(f'file: for spikemat_ind: {spikemat_ind} does not exist or could not be read! Skipping.')
        pass
## END for spikemat_ind in spikemat_list....

ripple_marginals
# Out:
# session_idx: 1, session: rat2day1
# file: for spikemat_ind: 63 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 64 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 65 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 66 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 67 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 68 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 69 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 70 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 71 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 72 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 73 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 74 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 75 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 76 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 77 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 78 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 79 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 80 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 81 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 82 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 83 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 84 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 85 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 86 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 87 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 88 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 89 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 90 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 91 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 92 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 93 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 94 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 95 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 96 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 97 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 98 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 99 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 100 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 101 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 102 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 103 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 104 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 105 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 106 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 107 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 108 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 109 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 110 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 111 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 112 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 113 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 114 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 115 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 116 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 117 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 118 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 119 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 120 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 121 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 122 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 123 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 124 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 125 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 126 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 127 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 128 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 129 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 130 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 131 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 132 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 133 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 134 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 135 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 136 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 137 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 138 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 139 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 140 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 141 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 142 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 143 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 144 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 145 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 146 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 147 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 148 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 149 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 150 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 151 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 152 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 153 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 154 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 155 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 156 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 157 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 158 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 159 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 160 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 161 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 162 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 163 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 164 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 165 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 166 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 167 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 168 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 169 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 170 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 171 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 172 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 173 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 174 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 175 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 176 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 177 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 178 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 179 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 180 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 181 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 182 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 183 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 184 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 185 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 186 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 187 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 188 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 189 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 190 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 191 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 192 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 193 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 194 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 195 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 196 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 197 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 198 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 199 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 200 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 201 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 202 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 203 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 204 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 205 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 206 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 207 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 208 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 209 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 210 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 211 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 212 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 213 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 214 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 215 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 216 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 217 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 218 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 219 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 220 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 221 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 222 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 223 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 224 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 225 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 226 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 227 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 228 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 229 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 230 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 231 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 232 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 233 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 234 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 235 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 236 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 237 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 238 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 239 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 240 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 241 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 242 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 243 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 244 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 245 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 246 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 247 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 248 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 249 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 250 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 251 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 252 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 253 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 254 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 255 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 256 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 257 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 258 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 259 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 260 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 261 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 262 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 263 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 264 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 265 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 266 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 267 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 268 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 269 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 270 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 271 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 272 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 273 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 274 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 275 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 276 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 277 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 278 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 279 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 280 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 281 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 282 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 283 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 284 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 285 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 286 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 287 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 288 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 289 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 290 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 291 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 292 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 293 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 294 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 295 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 296 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 297 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 298 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 299 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 300 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 301 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 302 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 303 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 304 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 305 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 306 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 307 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 308 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 309 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 310 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 311 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 312 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 313 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 314 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 315 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 316 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 317 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 318 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 319 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 320 does not exist or could not be read! Skipping.
# file: for spikemat_ind: 321 does not exist or could not be read! Skipping.
# {0: <replay_structure.marginals.All_Models_Marginals at 0x20c06ab2910>,
#  1: <replay_structure.marginals.All_Models_Marginals at 0x20c01b3dd60>,
#  2: <replay_structure.marginals.All_Models_Marginals at 0x20c037825e0>,
#  3: <replay_structure.marginals.All_Models_Marginals at 0x20c037823d0>,
#  4: <replay_structure.marginals.All_Models_Marginals at 0x20c037828e0>,
#  5: <replay_structure.marginals.All_Models_Marginals at 0x20c03782370>,
#  6: <replay_structure.marginals.All_Models_Marginals at 0x20c03782280>,
#  7: <replay_structure.marginals.All_Models_Marginals at 0x20c03782ca0>,
#  8: <replay_structure.marginals.All_Models_Marginals at 0x20c037825b0>,
#  9: <replay_structure.marginals.All_Models_Marginals at 0x20c03782a90>,
#  10: <replay_structure.marginals.All_Models_Marginals at 0x20c03782c40>,
#  11: <replay_structure.marginals.All_Models_Marginals at 0x20c037823a0>,
#  12: <replay_structure.marginals.All_Models_Marginals at 0x20c03782130>,
#  13: <replay_structure.marginals.All_Models_Marginals at 0x20c037827f0>,
#  14: <replay_structure.marginals.All_Models_Marginals at 0x20c03782190>,
#  15: <replay_structure.marginals.All_Models_Marginals at 0x20c03782be0>,
#  16: <replay_structure.marginals.All_Models_Marginals at 0x20c03782670>,
#  17: <replay_structure.marginals.All_Models_Marginals at 0x20c03782730>,
#  18: <replay_structure.marginals.All_Models_Marginals at 0x20c03782250>,
#  19: <replay_structure.marginals.All_Models_Marginals at 0x20c03782490>,
#  20: <replay_structure.marginals.All_Models_Marginals at 0x20c03782550>,
#  21: <replay_structure.marginals.All_Models_Marginals at 0x20c03782640>,
#  22: <replay_structure.marginals.All_Models_Marginals at 0x20c03782430>,
#  23: <replay_structure.marginals.All_Models_Marginals at 0x20c03782af0>,
#  24: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24400>,
#  25: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf247c0>,
#  26: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24a90>,
#  27: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf247f0>,
#  28: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24550>,
#  29: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24430>,
#  30: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24040>,
#  31: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24ac0>,
#  32: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24070>,
#  33: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf246a0>,
#  34: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf248e0>,
#  35: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf246d0>,
#  36: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf249d0>,
#  37: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24a30>,
#  38: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf241f0>,
#  39: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24850>,
#  40: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24520>,
#  41: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24f40>,
#  42: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf248b0>,
#  43: <replay_structure.marginals.All_Models_Marginals at 0x20c6cf24100>,
#  44: <replay_structure.marginals.All_Models_Marginals at 0x20c06ac4190>,
#  45: <replay_structure.marginals.All_Models_Marginals at 0x20c06ac41c0>,
#  46: <replay_structure.marginals.All_Models_Marginals at 0x20c06ac4070>,
#  47: <replay_structure.marginals.All_Models_Marginals at 0x20c06ac4040>,
#  48: <replay_structure.marginals.All_Models_Marginals at 0x20c16dab2e0>,
#  49: <replay_structure.marginals.All_Models_Marginals at 0x20c06aa8e20>,
#  50: <replay_structure.marginals.All_Models_Marginals at 0x20c06aa8850>,
#  51: <replay_structure.marginals.All_Models_Marginals at 0x20c06aa8fd0>,
#  52: <replay_structure.marginals.All_Models_Marginals at 0x20c0379bfa0>,
#  53: <replay_structure.marginals.All_Models_Marginals at 0x20c0379b970>,
#  54: <replay_structure.marginals.All_Models_Marginals at 0x20c0379be80>,
#  55: <replay_structure.marginals.All_Models_Marginals at 0x20c0379bf70>,
#  56: <replay_structure.marginals.All_Models_Marginals at 0x20c0379b4c0>,
#  57: <replay_structure.marginals.All_Models_Marginals at 0x20c0379b6a0>,
#  58: <replay_structure.marginals.All_Models_Marginals at 0x20c0379b1c0>,
#  59: <replay_structure.marginals.All_Models_Marginals at 0x20c0379b820>,
#  60: <replay_structure.marginals.All_Models_Marginals at 0x20c03781eb0>,
#  61: <replay_structure.marginals.All_Models_Marginals at 0x20c03781970>,
#  62: <replay_structure.marginals.All_Models_Marginals at 0x20c03781d60>}

# %%
# load model comparison results
mc_results = read_write.load_model_comparison_results(session, meta.Ripple_Data.default_time_window_ms, meta.Ripple_Data.name, meta.Ripple_Data.default_likelihood_function)

# %%
# load Pfeiffer & Foster (2013) classification
rd = read_write.load_ratday_data(session)
pf_trajectories = rd.data['significant_ripples']
# Out:
# loading  H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\data\ratday\rat2day1_4cm.obj

# %%
# load my own implementation of Pfeiffer & Foster (2013) trajectory extraction
decoding_type = 'map'
pf_analysis = read_write.load_pf_analysis(session, meta.Ripples_PF_Data.default_time_window_ms, meta.Ripples_PF_Data.name, decoding_type)
pf_trajectories = np.array([i for i in range(len(pf_analysis.results['significant_trajectory'])) if pf_analysis.results['significant_trajectory'][i]])

# loading  /Users/emmakrause/Documents/PhD/Lab/replay_structure/results_final/ripples/rat1day1_4cm_3ms_poisson_model_comparison.obj
# loading  /Users/emmakrause/Documents/PhD/Lab/replay_structure/data_final/ratday/rat1day1_4cm.obj
# loading  /Users/emmakrause/Documents/PhD/Lab/replay_structure/results_final/ripples_pf/rat1day1_4cm_20ms_pf_analysis_map.obj

# %%
ripples_plot = [15, 73, 23, 131]
n_ripples_plot = len(ripples_plot)

figure_width = 6.5
figure_height = 4.5
left_margin = 0.07
header_height = 0.1

imshow_height = 1 / figure_height * 0.6
imshow_width = 1 / figure_width * 0.6
barplot_height = 1 / figure_height * 0.6
barplot_width = 1.6 / figure_width * 0.6

w_spacing = 0.02
h_spacing = 0.09

title_padding = 7

model_names = ["Diffusion", "Momentum", "Stationary", "Gaussian", "Random"]

fig = plt.figure(
    figsize=(figure_width, figure_height), dpi=150, facecolor="w", edgecolor="k"
)


# add marginals
ax = dict()
for i in range(meta.N_MODELS):
    for j in range(n_ripples_plot):

        left = left_margin + (imshow_width * i) + w_spacing * i
        bottom = 1 - header_height - imshow_height * (j + 1) - h_spacing * j

        ax[i, j] = fig.add_axes([left, bottom, imshow_width, imshow_height])
        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])
        for axis in ['top','bottom','left','right']:
            ax[i,j].spines[axis].set_linewidth(1)

        if j == 0:
            ax[i, j].set_title(model_names[i], pad=title_padding, fontsize=7)

        if (i == 0) & (j == 0):
            ax[i, j].set_xticks([0, 49])
            ax[i, j].set_yticks([0, 49])
            ax[i, j].set_xticklabels(["0", "2m"])
            ax[i, j].set_yticklabels(["0", "2m"])
            ax[i, j].set_xlabel("x position", labelpad=-4)
            ax[i, j].set_ylabel("y position", labelpad=-7)
            ax[i, j].tick_params(axis="both", pad=0.08)
            
        if (i == (meta.N_MODELS-1)) &( j == (0)):
            im = ax[i,j].imshow(get_marginal_sum(ripple_marginals[ripples_plot[j]].marginals[meta.MODELS_AS_STR[i]]),
                          aspect='auto', origin='lower', cmap='inferno',vmin=np.log(.001), vmax=np.log(4))
            
            axins1 = inset_axes(ax[i,j],
                    width="75%",  
                    height="8%",  
                    loc='lower right',
                    bbox_to_anchor=(0, -.13, 1, 1),
                    bbox_transform=ax[i,j].transAxes,
                    borderpad=0)

            cbar = fig.colorbar(im, cax=axins1, orientation="horizontal", ticks=np.log([.01, .1, 1]))
            cbar.ax.set_xticklabels(['0.01', '0.1', '1'])
            cbar.ax.tick_params(pad=1, length=3)
            
            
            axins1.set_frame_on(True)
            for axis in ['top','bottom','left','right']:
                axins1.spines[axis].set_linewidth(0.5)

            axins1.xaxis.set_ticks_position("bottom")
            axins1.tick_params(labelsize=4)
        
        else:
            ax[i,j].imshow(get_marginal_sum(ripple_marginals[ripples_plot[j]].marginals[meta.MODELS_AS_STR[i]]),
                          aspect='auto', origin='lower', cmap='inferno',vmin=np.log(.001), vmax=np.log(4))
        

# add model probabilities
for j in range(n_ripples_plot):
    left = left_margin + (imshow_width * meta.N_MODELS) + w_spacing * meta.N_MODELS + .03
    bottom = 1 - header_height - imshow_height * (j + 1) - h_spacing * j
    
    x_ticks = np.arange(meta.N_MODELS) + .5

    ax[meta.N_MODELS, j] = fig.add_axes([left, bottom, barplot_width, barplot_height])
    ax[meta.N_MODELS, j].set_xticks(x_ticks)
    ax[meta.N_MODELS, j].set_xticklabels(
        model_names, fontsize=small_axislabel_fontsize, rotation=40, ha="right"  # position=(-1, 0.04)
    )
    ax[meta.N_MODELS, j].tick_params(axis="x", pad=0.08)
    ax[meta.N_MODELS, j].set_yticks([])
    ax[meta.N_MODELS, j].set_ylabel('p(M|$x_{1:T}$)', labelpad=-3)
    ax[meta.N_MODELS, j].spines["right"].set_visible(False)
    ax[meta.N_MODELS, j].spines["top"].set_visible(False)
    ax[meta.N_MODELS, j].set_ylim([0,1])
    ax[meta.N_MODELS, j].set_yticks([0,1])
    ax[meta.N_MODELS, j].set_yticklabels([0,1])
    
    
    ripple_p_models = get_p_models(mc_results.results_dataframe[meta.MODELS_AS_STR].iloc[ripples_plot[j]].values)
    ax[meta.N_MODELS, j].bar(x_ticks, ripple_p_models, width=.5, color='darkorange', alpha=.7)

# add Pfeiffer & Foster (2013) method
i = meta.N_MODELS + 1
for j in range(n_ripples_plot):
    left = (
        left_margin
        + (imshow_width * (meta.N_MODELS) + barplot_width)
        + w_spacing * (meta.N_MODELS + 1) + .03 + .02
    )
    bottom = 1 - header_height - imshow_height * (j + 1) - h_spacing * j
    ax[i, j] = fig.add_axes([left, bottom, imshow_width, imshow_height])
    ax[i, j].set_xticks([])
    ax[i, j].set_yticks([])
    
    for axis in ['top','bottom','left','right']:
                ax[i,j].spines[axis].set_linewidth(1)


    if j == 0:
        ax[i, j].set_title("Traditional\nMethod", pad=title_padding)
        
    posteriors_plot = np.exp(pf_analysis.results["posteriors"][ripples_plot[j]])[:,pf_analysis.results['trajectory_start_ind'][ripples_plot[j]]:pf_analysis.results['trajectory_end_ind'][ripples_plot[j]]]
    ax[i,j].imshow(get_marginal_sum(posteriors_plot),
                      aspect='auto', origin='lower', cmap='inferno',vmin=np.log(.001), vmax=np.log(4))
    ax[i,j].plot(pf_analysis.results['trajectory_map_positions'][ripples_plot[j]][:,1]/4,
                pf_analysis.results['trajectory_map_positions'][ripples_plot[j]][:,0]/4,
                color='seagreen', linewidth=.8, linestyle='-', label='Point estimate\ntrajectory')
    if pf_analysis.results["significant_trajectory"][ripples_plot[j]]:
        ax[i,j].set_xlabel("Classified as\nTrajectory", labelpad=1.8, fontsize=5)
    else:
        ax[i,j].set_xlabel("Not Classified", labelpad=1.8, fontsize=5)
    if j == (n_ripples_plot-1):
        ax[i,j].legend(frameon=False, fontsize=6, bbox_to_anchor=(1.5,-.2,0,0))
    
    
ax[0,0].text(-.4,1.4, "a", size=8, transform=ax[0,0].transAxes, fontweight='bold')
ax[5,0].text(-.2,1.4, "b", size=8, transform=ax[5,0].transAxes, fontweight='bold')
ax[6,0].text(-.3,1.4, "c", size=8, transform=ax[6,0].transAxes, fontweight='bold')

for i in range(n_ripples_plot):
    ax[0,i].text(-.5,.2, f"SWR {ripples_plot[i]}", size=7, transform=ax[0,i].transAxes, rotation=90)


plt.savefig(os.path.join(meta.FIGURES_PATH, "Figure2.svg"), dpi=300, transparent=True)

rect = plt.Rectangle(
    (0, 0), 1, 1, fill=False, color="k", lw=.5, alpha=.2,
    zorder=1000, transform=fig.transFigure, figure=fig
)
fig.patches.extend([rect])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 77
#      74             axins1.tick_params(labelsize=4)
#      76         else:
# ---> 77             ax[i,j].imshow(get_marginal_sum(ripple_marginals[ripples_plot[j]].marginals[meta.MODELS_AS_STR[i]]),
#      78                           aspect='auto', origin='lower', cmap='inferno',vmin=np.log(.001), vmax=np.log(4))
#      81 # add model probabilities
#      82 for j in range(n_ripples_plot):
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\utils.py:308, in get_marginal_sum(marginals, n_bins)
#     306 if len(marginals.shape) > 1:
#     307     marginal_norm = marginals / np.sum(marginals, axis=0)
# --> 308     marginal_2d = np.reshape(marginal_norm, (n_bins, n_bins, marginals.shape[1]))
#     309     marginal_plot = np.log(np.nansum(marginal_2d, axis=2))
#     310 else:
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File h:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\Spike3D\.venv\lib\site-packages\numpy\core\fromnumeric.py:298, in reshape(a, newshape, order)
#     198 @array_function_dispatch(_reshape_dispatcher)
#     199 def reshape(a, newshape, order='C'):
#     200     """
#     201     Gives a new shape to an array without changing its data.
#     202
#    (...)
#     296            [5, 6]])
#     297     """
# --> 298     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File h:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\Spike3D\.venv\lib\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# ValueError: cannot reshape array of size 464400 into shape (50,50,129)

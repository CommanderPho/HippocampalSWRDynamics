# %% [markdown]
# Connected to .venv (Python 3.9.13)

# %%
from types import SimpleNamespace
from replay_structure.config import RatDay_Preprocessing_Parameters
from replay_structure.ratday_preprocessing import RatDay_Preprocessing
# from scripts.local.preprocess_spikemat_data import run_spikemat_preprocessing
from replay_structure.read_write import save_ratday_data
from replay_structure.metadata import (
    DATA_PATH,
    string_to_session_indicator,
    Session_List,
    Session_Name,
)

import numpy as np
import matplotlib.pyplot as plt

SMALL_SIZE = 5
MEDIUM_SIZE = 6
BIGGER_SIZE = 7

plt.rc('font', size=SMALL_SIZE, family='sans-serif')          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('lines', linewidth=2, color='r')
plt.rcParams['font.sans-serif'] = ['Helvetica']

import replay_structure.metadata as meta
import replay_structure.read_write as read_write

from pyphoplacecellanalysis.SpecificResults.PendingNotebookCode import RepoConvert_HippocampalSWRDynamics
# Out:
# H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\NeuroPy\neuropy\utils\mixins\time_slicing.py:405: UserWarning: registration of accessor <class 'neuropy.utils.mixins.time_slicing.TimePointEventAccessor'> under name 'time_point_event' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class TimePointEventAccessor(TimeColumnAliasesProtocol, TimeSlicableObjectProtocol, DataframeMetadataProtocol):
# h:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\Spike3D\.venv\lib\site-packages\hdf5storage\utilities.py:44: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
bin_size_cm = 4
rotate_placefields = False
# grid_bin = curr_active_pipeline.sess.config.grid_bin
# bin_size_cm = min(grid_bin)
print(f'bin_size_cm: {bin_size_cm}')
ratday_params = RatDay_Preprocessing_Parameters(bin_size_cm=bin_size_cm, rotate_placefields=rotate_placefields)
ratday_params

# matlab_like_data
ratday_from_bapun = RatDay_Preprocessing(matlab_like_data, ratday_params)
# Out:
# bin_size_cm: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 ratday_params
#       9 # matlab_like_data
# ---> 10 ratday_from_bapun = RatDay_Preprocessing(matlab_like_data, ratday_params)
#
# NameError: name 'matlab_like_data' is not defined

# %%
session_indicator = Session_Name(rat=2, day=1) # string_to_session_indicator(Session_Name(rat=0, day=4))
assert isinstance(session_indicator, Session_Name)
session_indicator
# Out:
# Session_Name(rat=2, day=1)

# %%
from replay_structure.metadata import SESSION_RATDAY
print(f'SESSION_RATDAY: {SESSION_RATDAY}')
from replay_structure.pipelines.session_pipeline import (
    DEFAULT_LIKELIHOOD,
    DEFAULT_TIME_WINDOW_MS,
    DEFAULT_TRAJECTORY_SD_METERS,
    run_session_pipeline,
)


session: int = 1
bin_size_cm: int = 4
time_window_ms: int = DEFAULT_TIME_WINDOW_MS # 0.003
likelihood_function: str = DEFAULT_LIKELIHOOD
filename_ext: str = ''
trajectory_sd_meters: float = DEFAULT_TRAJECTORY_SD_METERS
skip_gridsearch: bool = True
force_ratday_preprocess: bool = False
run_marginals: bool = True
run_diffusion_constant: bool = True
continue_on_gridsearch_error: bool = False
strict: bool = False
dry_run: bool = False
# Out:
# SESSION_RATDAY: {0: {'rat': 1, 'day': 1, 'n_SWRs': 0}, 1: {'rat': 2, 'day': 1, 'n_SWRs': 0}}

# %%
run_session_pipeline(
    session=session,
    bin_size_cm=bin_size_cm,
    time_window_ms=time_window_ms,
    likelihood_function=likelihood_function,
    filename_ext=filename_ext,
    trajectory_sd_meters=trajectory_sd_meters,
    skip_gridsearch=True,
    force_ratday_preprocess=False,
    run_marginals_phase=False,
    run_diffusion_constant_phase=False,
    continue_on_gridsearch_error=continue_on_gridsearch_error,
    strict=strict,
    dry_run=dry_run,
)
# Out:
# [OK] preprocess_ratday_data: using existing ratday file: H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\data\ratday\rat2day1_4cm.obj
#
# === preprocess_spikemat_data_ripples ===
# run_preprocess_spikemat(data_type=ripples, session=1, bin_size_cm=4, time_window_ms=3, filename_ext='')
# running session rat2day1 with 4cm binsand 3ms time window.
# loading  H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\data\ratday\rat2day1_4cm.obj
# Getting ripple spikemats
# [48 72 48 ... 15 25 25]
# [48 72 48 ... 15 25 25]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 run_session_pipeline(
#       2     session=session,
#       3     bin_size_cm=bin_size_cm,
#       4     time_window_ms=time_window_ms,
#       5     likelihood_function=likelihood_function,
#       6     filename_ext=filename_ext,
#       7     trajectory_sd_meters=trajectory_sd_meters,
#       8     skip_gridsearch=True,
#       9     force_ratday_preprocess=False,
#      10     run_marginals_phase=False,
#      11     run_diffusion_constant_phase=False,
#      12     continue_on_gridsearch_error=continue_on_gridsearch_error,
#      13     strict=strict,
#      14     dry_run=dry_run,
#      15 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\session_pipeline.py:208, in run_session_pipeline(session, bin_size_cm, time_window_ms, likelihood_function, filename_ext, trajectory_sd_meters, skip_gridsearch, force_ratday_preprocess, run_marginals_phase, run_diffusion_constant_phase, continue_on_gridsearch_error, strict, dry_run)
#     195 else:
#     196     _run_step(
#     197         results,
#     198         "preprocess_ratday_data",
#    (...)
#     206         ),
#     207     )
# --> 208 _run_step(
#     209     results,
#     210     "preprocess_spikemat_data_ripples",
#     211     critical=True,
#     212     dependencies=["preprocess_ratday_data"],
#     213     strict=strict,
#     214     action=lambda: _execute_or_print(
#     215         dry_run,
#     216         f"run_preprocess_spikemat(data_type=ripples, session={session}, bin_size_cm={bin_size_cm}, time_window_ms={time_window_ms}, filename_ext={filename_ext!r})",
#     217         lambda: run_preprocess_spikemat(
#     218             data_type=RIPPLES_DATA_TYPE,
#     219             session=session_indicator,
#     220             bin_size_cm=bin_size_cm,
#     221             time_window_ms=time_window_ms,
#     222             filename_ext=filename_ext,
#     223         ),
#     224     ),
#     225 )
#     226 _run_step(
#     227     results,
#     228     "reformat_data_for_structure_analysis_ripples",
#    (...)
#     243     ),
#     244 )
#     245 _run_step(
#     246     results,
#     247     "run_model_stationary",
#    (...)
#     263     ),
#     264 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\session_pipeline.py:76, in _run_step(results, name, critical, dependencies, strict, action)
#      74 print(f"\n=== {name} ===")
#      75 try:
# ---> 76     action()
#      77 except Exception as exc:
#      78     traceback.print_exc()
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\session_pipeline.py:214, in run_session_pipeline.<locals>.<lambda>()
#     195 else:
#     196     _run_step(
#     197         results,
#     198         "preprocess_ratday_data",
#    (...)
#     206         ),
#     207     )
#     208 _run_step(
#     209     results,
#     210     "preprocess_spikemat_data_ripples",
#     211     critical=True,
#     212     dependencies=["preprocess_ratday_data"],
#     213     strict=strict,
# --> 214     action=lambda: _execute_or_print(
#     215         dry_run,
#     216         f"run_preprocess_spikemat(data_type=ripples, session={session}, bin_size_cm={bin_size_cm}, time_window_ms={time_window_ms}, filename_ext={filename_ext!r})",
#     217         lambda: run_preprocess_spikemat(
#     218             data_type=RIPPLES_DATA_TYPE,
#     219             session=session_indicator,
#     220             bin_size_cm=bin_size_cm,
#     221             time_window_ms=time_window_ms,
#     222             filename_ext=filename_ext,
#     223         ),
#     224     ),
#     225 )
#     226 _run_step(
#     227     results,
#     228     "reformat_data_for_structure_analysis_ripples",
#    (...)
#     243     ),
#     244 )
#     245 _run_step(
#     246     results,
#     247     "run_model_stationary",
#    (...)
#     263     ),
#     264 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\session_pipeline.py:92, in _execute_or_print(dry_run, description, action)
#      90 if dry_run:
#      91     return
# ---> 92 action()
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\session_pipeline.py:217, in run_session_pipeline.<locals>.<lambda>.<locals>.<lambda>()
#     195 else:
#     196     _run_step(
#     197         results,
#     198         "preprocess_ratday_data",
#    (...)
#     206         ),
#     207     )
#     208 _run_step(
#     209     results,
#     210     "preprocess_spikemat_data_ripples",
#     211     critical=True,
#     212     dependencies=["preprocess_ratday_data"],
#     213     strict=strict,
#     214     action=lambda: _execute_or_print(
#     215         dry_run,
#     216         f"run_preprocess_spikemat(data_type=ripples, session={session}, bin_size_cm={bin_size_cm}, time_window_ms={time_window_ms}, filename_ext={filename_ext!r})",
# --> 217         lambda: run_preprocess_spikemat(
#     218             data_type=RIPPLES_DATA_TYPE,
#     219             session=session_indicator,
#     220             bin_size_cm=bin_size_cm,
#     221             time_window_ms=time_window_ms,
#     222             filename_ext=filename_ext,
#     223         ),
#     224     ),
#     225 )
#     226 _run_step(
#     227     results,
#     228     "reformat_data_for_structure_analysis_ripples",
#    (...)
#     243     ),
#     244 )
#     245 _run_step(
#     246     results,
#     247     "run_model_stationary",
#    (...)
#     263     ),
#     264 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\preprocessing_pipeline.py:134, in run_preprocess_spikemat(data_type, session, bin_size_cm, time_window_ms, filename_ext)
#     132     time_window_ms = data_type.default_time_window_ms
#     133 if session is not None:
# --> 134     _run_spikemat_preprocessing_for_session(data_type, session, bin_size_cm, time_window_ms, filename_ext)
#     135     return
#     136 for session_indicator in data_type.session_list:
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\pipelines\preprocessing_pipeline.py:88, in _run_spikemat_preprocessing_for_session(data_type, session_indicator, bin_size_cm, time_window_ms, filename_ext)
#      86 if isinstance(data_type.name, Ripples):
#      87     ripple_params = Ripple_Preprocessing_Parameters(ratday_data.params, time_window_ms=time_window_ms)
# ---> 88     spikemat_data = Ripple_Preprocessing(ratday_data, ripple_params)
#      89 elif isinstance(data_type.name, Run_Snippets):
#      90     run_snippet_params = Run_Snippet_Preprocessing_Parameters(ratday_data.params, time_window_ms=time_window_ms)
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\ripple_preprocessing.py:28, in Ripple_Preprocessing.__init__(self, ratday, params, popburst_times_s)
#      23 self.pf_matrix = utils.get_pf_matrix(
#      24     ratday.place_field_data["place_fields"],
#      25     ratday.place_field_data["place_cell_ids"],
#      26 )
#      27 print("Getting ripple spikemats")
# ---> 28 self.ripple_info = self.get_ripple_info(
#      29     ratday, popburst_times_s=popburst_times_s
#      30 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\ripple_preprocessing.py:57, in Ripple_Preprocessing.get_ripple_info(self, ratday, popburst_times_s)
#      50     np.random.shuffle(spike_ids)
#      51 print(spike_ids)
#      52 (
#      53     ripple_info["spikemats_fullripple"],
#      54     ripple_info["spikemats_popburst"],
#      55     ripple_info["popburst_times_s"],
#      56     ripple_info["avg_spikes_per_s_smoothed"],
# ---> 57 ) = self.get_spikemats(
#      58     spike_ids,
#      59     ratday.data["spike_times_s"],
#      60     ratday.place_field_data["place_cell_ids"],
#      61     ratday.data["ripple_times_s"],
#      62     popburst_times_s=popburst_times_s,
#      63 )
#      65 (
#      66     ripple_info["popburst_mean_firing_rate_array"],
#      67     ripple_info["popburst_mean_firing_rate_matrix"],
#      68 ) = self.calc_popburst_firing_rate_array(ripple_info["spikemats_popburst"])
#      69 ripple_info["firing_rate_scaling"] = self.calc_firing_rate_scaling(
#      70     ratday.place_field_data["mean_firing_rate_array"][
#      71         ratday.place_field_data["place_cell_ids"]
#      72     ],
#      73     ripple_info["popburst_mean_firing_rate_array"],
#      74 )
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\ripple_preprocessing.py:102, in Ripple_Preprocessing.get_spikemats(self, spike_ids, spike_times, place_cell_ids, ripple_times, popburst_times_s)
#     100 ripple_start = ripple_times[ripple_num][0]
#     101 ripple_end = ripple_times[ripple_num][1]
# --> 102 spikemats_fullripple[ripple_num] = utils.get_spikemat(
#     103     spike_ids,
#     104     spike_times,
#     105     place_cell_ids,
#     106     ripple_start,
#     107     ripple_end,
#     108     self.params.time_window_s,
#     109     self.params.time_window_advance_s,
#     110 )
#     111 # if self.params.select_population_burst:
#     112 if popburst_times_s is None:
#
# File H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\HippocampalSWRDynamics\replay_structure\utils.py:176, in get_spikemat(spike_ids, spike_times, place_cell_ids, start_time, end_time, time_window_s, time_window_advance_s)
#     174 sort_order = np.argsort(spike_times, kind="stable")
#     175 spike_times_sorted = spike_times[sort_order]
# --> 176 spike_ids_sorted = spike_ids[sort_order]
#     177 start_inds = np.searchsorted(spike_times_sorted, bin_starts, side="left")
#     178 end_inds = np.searchsorted(spike_times_sorted, bin_ends, side="left")
#
# KeyboardInterrupt:

# %% [markdown]
# Restarted .venv (Python 3.9.13)

# %%
from types import SimpleNamespace
from replay_structure.config import RatDay_Preprocessing_Parameters
from replay_structure.ratday_preprocessing import RatDay_Preprocessing
# from scripts.local.preprocess_spikemat_data import run_spikemat_preprocessing
from replay_structure.read_write import save_ratday_data
from replay_structure.metadata import (
    DATA_PATH,
    string_to_session_indicator,
    Session_List,
    Session_Name,
)

import numpy as np
import matplotlib.pyplot as plt

SMALL_SIZE = 5
MEDIUM_SIZE = 6
BIGGER_SIZE = 7

plt.rc('font', size=SMALL_SIZE, family='sans-serif')          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rc('lines', linewidth=2, color='r')
plt.rcParams['font.sans-serif'] = ['Helvetica']

import replay_structure.metadata as meta
import replay_structure.read_write as read_write

from pyphoplacecellanalysis.SpecificResults.PendingNotebookCode import RepoConvert_HippocampalSWRDynamics
# Out:
# H:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\NeuroPy\neuropy\utils\mixins\time_slicing.py:405: UserWarning: registration of accessor <class 'neuropy.utils.mixins.time_slicing.TimePointEventAccessor'> under name 'time_point_event' for type <class 'pandas.core.frame.DataFrame'> is overriding a preexisting attribute with the same name.
#   class TimePointEventAccessor(TimeColumnAliasesProtocol, TimeSlicableObjectProtocol, DataframeMetadataProtocol):
# h:\TEMP\Spike3DEnv_ExploreUpgrade\Spike3DWorkEnv\Spike3D\.venv\lib\site-packages\hdf5storage\utilities.py:44: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version

# %%
bin_size_cm = 4
rotate_placefields = False
# grid_bin = curr_active_pipeline.sess.config.grid_bin
# bin_size_cm = min(grid_bin)
print(f'bin_size_cm: {bin_size_cm}')
ratday_params = RatDay_Preprocessing_Parameters(bin_size_cm=bin_size_cm, rotate_placefields=rotate_placefields)
ratday_params

# matlab_like_data
ratday_from_bapun = RatDay_Preprocessing(matlab_like_data, ratday_params)
session_indicator = Session_Name(rat=2, day=1) # string_to_session_indicator(Session_Name(rat=0, day=4))
assert isinstance(session_indicator, Session_Name)
session_indicator
# Out:
# bin_size_cm: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       7 ratday_params
#       9 # matlab_like_data
# ---> 10 ratday_from_bapun = RatDay_Preprocessing(matlab_like_data, ratday_params)
#      11 session_indicator = Session_Name(rat=2, day=1) # string_to_session_indicator(Session_Name(rat=0, day=4))
#      12 assert isinstance(session_indicator, Session_Name)
#
# NameError: name 'matlab_like_data' is not defined

# %%
from replay_structure.metadata import SESSION_RATDAY
print(f'SESSION_RATDAY: {SESSION_RATDAY}')
from replay_structure.pipelines.session_pipeline import (
    DEFAULT_LIKELIHOOD,
    DEFAULT_TIME_WINDOW_MS,
    DEFAULT_TRAJECTORY_SD_METERS,
    run_session_pipeline,
)


session: int = 1
bin_size_cm: int = 4
time_window_ms: int = DEFAULT_TIME_WINDOW_MS # 0.003
likelihood_function: str = DEFAULT_LIKELIHOOD
filename_ext: str = ''
trajectory_sd_meters: float = DEFAULT_TRAJECTORY_SD_METERS
skip_gridsearch: bool = True
force_ratday_preprocess: bool = False
run_marginals: bool = False
run_diffusion_constant: bool = True
continue_on_gridsearch_error: bool = False
strict: bool = False
dry_run: bool = False
# Out:
# SESSION_RATDAY: {0: {'rat': 1, 'day': 1, 'n_SWRs': 0}, 1: {'rat': 2, 'day': 1, 'n_SWRs': 0}}

# %%
run_session_pipeline(
    session=session,
    bin_size_cm=bin_size_cm,
    time_window_ms=time_window_ms,
    likelihood_function=likelihood_function,
    filename_ext=filename_ext,
    trajectory_sd_meters=trajectory_sd_meters,
    skip_gridsearch=True,
    force_ratday_preprocess=False,
    run_marginals_phase=False,
    run_diffusion_constant_phase=False,
    continue_on_gridsearch_error=continue_on_gridsearch_error,
    strict=strict,
    dry_run=dry_run,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_session_pipeline(
#       2     session=session,
#       3     bin_size_cm=bin_size_cm,
#       4     time_window_ms=time_window_ms,
#       5     likelihood_function=likelihood_function,
#       6     filename_ext=filename_ext,
#       7     trajectory_sd_meters=trajectory_sd_meters,
#       8     skip_gridsearch=True,
#       9     force_ratday_preprocess=False,
#      10     run_marginals_phase=False,
#      11     run_diffusion_constant_phase=False,
#      12     continue_on_gridsearch_error=continue_on_gridsearch_error,
#      13     strict=strict,
#      14     dry_run=dry_run,
#      15 )
#
# TypeError: run_session_pipeline() got an unexpected keyword argument 'force_ratday_preprocess'
